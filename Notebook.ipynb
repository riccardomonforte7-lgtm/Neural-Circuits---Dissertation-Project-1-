# %% [markdown]
# ## Full Notebook ##

# %% [markdown]
# # SNR data
#
# Load relevant libraries and define custom functions.

# %%
# ============================================================
# 1. Data manipulation
# ============================================================
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import SpectralClustering

from scipy.cluster import hierarchy
from sklearn.metrics import silhouette_samples, silhouette_score
import pandas as pd
import numpy as np
import plotly.express as px
import pandas as pd

# ============================================================
# 2. Plotting
# ============================================================

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns


# ============================================================
# 3. Neuron / 3D visualisation
# ============================================================

from brainrender import Scene
from brainrender.actors import Points

import vedo
vedo.settings.default_backend = "vtk"


# ============================================================
# 4. Scikit-learn general
# ============================================================

import sklearn
import sklearn.preprocessing


# ============================================================
# 5. Preprocessing
# ============================================================

from sklearn.preprocessing import (
    StandardScaler,
    OneHotEncoder,
    OrdinalEncoder,
    LabelEncoder,
    TargetEncoder,
    FunctionTransformer
)

from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer, make_column_transformer
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA


# ============================================================
# 6. Pipelines
# ============================================================

from sklearn.pipeline import Pipeline, make_pipeline


# ============================================================
# 7. Model selection
# ============================================================

from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    KFold,
    StratifiedKFold
)


# ============================================================
# 8. Models
# ============================================================

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier


# ============================================================
# 9. Clustering
# ============================================================

from sklearn.cluster import KMeans, AgglomerativeClustering
from scipy.cluster import hierarchy
from sklearn.datasets import make_blobs


# ============================================================
# 10. Metrics and model evaluation
# ============================================================

from sklearn.metrics import (
    make_scorer,
    silhouette_samples,
    silhouette_score,
    mean_squared_error,
    r2_score,
    classification_report,
    ConfusionMatrixDisplay,
    RocCurveDisplay,
    roc_auc_score,
    accuracy_score,
    PrecisionRecallDisplay
)


# ============================================================
# 11. Visualisation of decision boundaries
# ============================================================

from sklearn.inspection import DecisionBoundaryDisplay


# ============================================================
# 12. Resampling utilities
# ============================================================

from sklearn.utils import resample


# ============================================================
# 13. Statistical tests
# ============================================================

from scipy.stats import chi2_contingency


# ============================================================
# 14. Custom functions
# ============================================================

def compute_wcv(labels, X):
    """
    Compute within-cluster variance.

    Parameters
    ----------
    labels : array-like
        Cluster labels assigned to each observation.
    X : array-like or DataFrame
        Feature matrix.

    Returns
    -------
    wcv : float
        Total within-cluster variance.
    """
    wcv = 0

    for cluster in np.unique(labels):
        X_cluster = X[labels == cluster]
        centroid = np.mean(X_cluster, axis=0)
        wcv_cluster = ((X_cluster - centroid) ** 2).sum().sum()
        wcv += wcv_cluster

    return wcv


def spectral_scorer_wcv(estimator, X, y=None):
    """
    Custom scorer for spectral clustering based on within-cluster variance.

    Returns the negative WCV because GridSearchCV maximizes the score.
    """
    labels = estimator.fit_predict(X)
    wcv = compute_wcv(labels, X)

    return -wcv


def spectral_scorer_sil(estimator, X, y=None):
    """
    Custom scorer for spectral clustering based on silhouette score.

    Returns the negative silhouette score because this was defined as a loss-like score.
    """
    labels = estimator.fit_predict(X)
    score = silhouette_score(X, labels, metric="cosine")

    return score

# %%
# To make this notebook's output identical at every run
rng = np.random.seed(0)

#Our objective is to cluster the data in the SNR database using the features describing the projection behaviour of the neurons.
#Once we have our clusters, we want to see if those are reflected by the predifined labels (rsp, orb, rsp_orb)

# load data
ec_snr_data = pd.read_csv("master_detailed_comment.csv")
ec_snr_data.head()
ec_snr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 68 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mouseID          237 non-null    int64
#  1   neuronNR         237 non-null    int64
#  2   neuron_ID        237 non-null    object
#  3   FRP_endpoint     237 non-null    int64
#  4   FRP_length       237 non-null    float64
#  5   SS_endpoint      237 non-null    int64
#  6   SS_length        237 non-null    float64
#  7   VIS_endpoint     237 non-null    int64
#  8   VIS_length       237 non-null    float64
#  9   VISpor_endpoint  237 non-null    int64
#  10  VISpor_length    237 non-null    float64
#  11  RSP_endpoint     237 non-null    int64
#  12  RSP_length       237 non-null    float64
#  13  PTLp_endpoint    237 non-null    int64
#  14  PTLp_length      237 non-null    float64
#  15  ORB_endpoint     237 non-null    int64
#  16  ORB_length       237 non-null    float64
#  17  MO_endpoint      237 non-null    int64
#  18  MO_length        237 non-null    float64
#  19  AUD_endpoint     237 non-null    int64
#  20  AUD_length       237 non-null    float64
#  21  ACA_endpoint     237 non-null    int64
#  22  ACA_length       237 non-null    float64
#  23  PL_endpoint      237 non-null    int64
#  24  PL_length        237 non-null    float64
#  25  ILA_endpoint     237 non-null    int64
#  26  ILA_length       237 non-null    float64
#  27  VISC_endpoint    237 non-null    int64
#  28  VISC_length      237 non-null    float64
#  29  AI_endpoint      237 non-null    int64
#  30  AI_length        237 non-null    float64
#  31  GU_endpoint      237 non-null    int64
#  32  GU_length        237 non-null    float64
#  33  TEa_endpoint     237 non-null    int64
#  34  TEa_length       237 non-null    float64
#  35  PERI_endpoint    237 non-null    int64
#  36  PERI_length      237 non-null    float64
#  37  ECT_endpoint     237 non-null    int64
#  38  ECT_length       237 non-null    float64
#  39  OLF_endpoint     237 non-null    int64
#  40  OLF_length       237 non-null    float64
#  41  PAR_endpoint     237 non-null    int64
#  42  PAR_length       237 non-null    float64
#  43  POST_endpoint    237 non-null    int64
#  44  POST_length      237 non-null    float64
#  45  PRE_endpoint     237 non-null    int64
#  46  PRE_length       237 non-null    float64
#  47  SUB_endpoint     237 non-null    int64
#  48  SUB_length       237 non-null    float64
#  49  HIP_endpoint     237 non-null    int64
#  50  HIP_length       237 non-null    float64
#  51  CLA_endpoint     237 non-null    int64
#  52  CLA_length       237 non-null    float64
#  53  EP_endpoint      237 non-null    int64
#  54  EP_length        237 non-null    float64
#  55  AMY_endpoint     237 non-null    int64
#  56  AMY_length       237 non-null    float64
#  57  STRd_endpoint    237 non-null    int64
#  58  STRd_length      237 non-null    float64
#  59  STRv_endpoint    237 non-null    int64
#  60  STRv_length      237 non-null    float64
#  61  x                237 non-null    float64
#  62  y                237 non-null    float64
#  63  z                237 non-null    float64
#  64  comment          77 non-null     object
#  65  injection        237 non-null    object
#  66  proj             160 non-null    object
#  67  count            237 non-null    int64
# dtypes: float64(32), int64(32), object(4)
# memory usage: 126.0+ KB

# %%
#Define the database that will be cleaned and preprocessed
df = ec_snr_data.copy()

#Keep in the database only the variables that explain connectivity patterns 
cols_to_drop = ["mouseID", "neuronNR", "neuron_ID", "x", "y", "z", "comment", "injection", "proj", "count"]

df = df.drop(columns=cols_to_drop)

# %%
plt.figure(figsize=(24, 20))
sns.heatmap(df.corr())
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2400x2000 with 2 Axes>

# %% [markdown]
# Length and endpoint appear to be highly correlated, we can remove either one from each of the encoded regions. Moreover, we clearly see some structure in the correlation patterns. We can use PCA before clustering to capture to move to a lower dimensional space and then apply PCA on the lower dimensional space.

# %%
#Get the columns that end with "_endpoint"
endpoint_cols = []

for col in df.columns:
    if col.endswith("_endpoint"):
        endpoint_cols.append(col)

# %%
#Remove endpoint columns from the dataframe
df = df.drop(columns=endpoint_cols)

# %%
#We will use _length columns as features on which perform the clustering
length_cols = []

for col in ec_snr_data.columns:
    if col.endswith("_length"):
        length_cols.append(col)

# %%
#Want to create our own labels to facilitate interpretation of clustering
#We will assign to each neuron the name of the most relevant regions it projects to. We compute the 90th percentile
#of each _length distribution and assign to the neuron the name of the region if the length of its axons
#in that region exceed the 90th percentile of the distribution of the length for that region.

#Compute 90th percentile for each length variable
thresholds = ec_snr_data[length_cols].quantile(0.90)

def assign_projection_label(row):
    labels = []
    
    for col in length_cols:
        if row[col] > thresholds[col]:
            label = col.replace("_length", "")
            labels.append(label)
    
    if len(labels) == 0:
        return "Not assigned"
    else:
        return "_".join(labels)

ec_snr_data["projection_label"] = ec_snr_data.apply(assign_projection_label, axis=1)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# projection_label
# Not assigned           46
# AMY                     4
# VISpor                  4
# PRE_HIP                 4
# STRd                    3
#                        ..
# VIS_VISpor_RSP_PTLp     1
# SS_MO_ACA               1
# ORB_ILA_AI_OLF          1
# VIS_VISpor_PTLp         1
# RSP_PRE_SUB             1
# Name: count, Length: 161, dtype: int64

# %%
#Create a combined label for plotting reasons that has both the original label (rsp, orb, rsp_orb) and the new custom label

my_labels = []

for elem in ec_snr_data["projection_label"]:
    my_labels.append(elem)

labels = []

for elem in ec_snr_data["proj"]:
    labels.append(elem)

combined_labels = []

for i in range(len(my_labels)):
    combined_label = str(my_labels[i]) + " \\\ " + str(labels[i])
    combined_labels.append(combined_label)

ec_snr_data["combined_labels"] = combined_labels
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\ '
# <>:16: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\ricca\AppData\Local\Temp\ipykernel_22988\1027093793.py:16: SyntaxWarning: invalid escape sequence '\ '
#   combined_label = str(my_labels[i]) + " \\\ " + str(labels[i])

# %%
#Scale the data (lenght have very different ranges)
scaler = StandardScaler()
df_transitory = scaler.fit_transform(df)

#Create new df with scaled features
df = pd.DataFrame(
    df_transitory,
    columns = df.columns,
    index = df.index
)

# %% [markdown]
# # PCA

# %%
pca = PCA()
pca.fit(df)
# Out:
# PCA()

# %%
#selecting number of components
explained_var = pca.explained_variance_
explained_var_ratio = pca.explained_variance_ratio_
x = np.linspace(1,len(explained_var),len(explained_var))
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
ax[0].plot(x, explained_var_ratio[0:200], 'k-', marker = 'o', markersize=4)
ax[1].plot(x,explained_var_ratio.cumsum()[0:200], 'k-', marker = 'o', markersize=4)
fig.tight_layout()
ax[0].set_xlim(0,100)
ax[1].set_xlim(0,100)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (0.0, 100.0)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1200x500 with 2 Axes>

# %% [markdown]
# the first 18 components explain more ore less 90% of variability

# %%
#Let's get the new feature matrix
pca2 = PCA(n_components = 18)
low_dim_df_trans = pca2.fit_transform(df)

low_dim_df = pd.DataFrame(
    low_dim_df_trans,
    columns = [f"PCA{i+1}" for i in range(low_dim_df_trans.shape[1])]
)

# %% [markdown]
# # Clustering

# %%
#get labels which will be used for plotting later
print(combined_labels[0:10])
#original labels
labels_df = ec_snr_data["proj"]
# Out:
# ['VISC_SUB_AMY_STRv \\\\ rsp_orb', 'ORB \\\\ rsp_orb', 'SS_MO_ACA_PERI_OLF_STRd_STRv \\\\ rsp_orb', 'Not assigned \\\\ nan', 'ORB_ILA_OLF_AMY_STRv \\\\ orb', 'ILA_GU \\\\ orb', 'SS_ORB_AUD_VISC_TEa_PERI_ECT_OLF_STRd \\\\ nan', 'CLA \\\\ orb', 'FRP_VISpor_MO_POST_STRd \\\\ rsp_orb', 'FRP_ORB_PL_ILA_CLA \\\\ orb']

# %% [markdown]
# tried also with euclidean distance and single linkage, but those models do not create cleare defined clusters as models that employ cosine dissimilarity and complete/average linkage

# %% [markdown]
# # Hierarchical Clustering - cosine dissimilary, complete linkage

# %%
hc_comp_cos = hierarchy.linkage(low_dim_df, method="complete", metric="cosine")
# Plot the dendrogram
fig, ax = plt.subplots(1, 1, figsize=(40,20))
hierarchy.dendrogram(hc_comp_cos, ax=ax, labels=np.asarray(combined_labels),
                     color_threshold=1.6, above_threshold_color='black', leaf_font_size = 10)
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 4000x2000 with 1 Axes>

# %%
cluster_labels = hierarchy.cut_tree(hc_comp_cos, height=1.6)
hc_comp_cos_1d_labels = cluster_labels[:, 0]

plot_df = low_dim_df.copy()
plot_df.columns = [f"Dim_{i+1}" for i in range(plot_df.shape[1])]
plot_df["hc_comp_cluster"] = hc_comp_cos_1d_labels.astype(str)

fig = px.scatter_3d(
    plot_df,
    x="Dim_1",
    y="Dim_2",
    z="Dim_3",
    color="hc_comp_cluster",
    hover_data=plot_df.columns)

fig.show()

ct = pd.crosstab(hc_comp_cos_1d_labels, labels_df)
print(ct)
# Out:
# proj   orb  rsp  rsp_orb
# row_0
# 0       39    3       23
# 1        8   25        5
# 2        1   30       26

# %%
#Compute the within cluster variation for clusters that range from 2 to 6
wcv_comp_cos = {}
for i in range(2,7):
    cluster_labels = hierarchy.cut_tree(hc_comp_cos, n_clusters=i)
    cluster_labels = cluster_labels[:, 0]
    wcv_comp_cos_i = compute_wcv(cluster_labels, low_dim_df)
    wcv_comp_cos[i] = wcv_comp_cos_i

# %%
#Compute and plot average silhouette score for a number of clusters ranging from 2 to 6

range_n_clusters = [2, 3, 4, 5, 6]
sil_hierarchical = {}

# Compute the hierarchical clustering linkage once
hc_comp_cos = hierarchy.linkage(low_dim_df, method="complete", metric="cosine")

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 1 columns
    fig, ax1 = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(low_dim_df) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    cluster_labels = hierarchy.cut_tree(hc_comp_cos, n_clusters=n_clusters)
    cluster_labels = cluster_labels[:, 0]

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(
        low_dim_df,
        cluster_labels,
        metric="cosine"
    )
    sil_hierarchical[n_clusters] = silhouette_avg
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(
        low_dim_df,
        cluster_labels,
        metric="cosine"
    )

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(
        "Silhouette analysis for Hierarchical clustering on sample data with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.2696264984174785
# For n_clusters = 3 The average silhouette_score is : 0.27975737450629273
# For n_clusters = 4 The average silhouette_score is : 0.25054418504122705
# For n_clusters = 5 The average silhouette_score is : 0.22733501983912485
# For n_clusters = 6 The average silhouette_score is : 0.26325508046203977
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>

# %% [markdown]
# # Hierarchical Clustering - cosine dissimilarity, average linkage

# %%
hc_avg_cos = hierarchy.linkage(low_dim_df, method="average", metric="cosine")
# Plot the dendrogram
fig, ax = plt.subplots(1, 1, figsize=(70,20))
hierarchy.dendrogram(hc_avg_cos, ax=ax, labels=np.asarray(combined_labels),
                     color_threshold=1, above_threshold_color='black', leaf_font_size = 10)

plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 7000x2000 with 1 Axes>

# %%
cluster_labels = hierarchy.cut_tree(hc_avg_cos, height=1)
hc_avg_cos_1d_labels = cluster_labels[:, 0]

plot_df["hc_avg_cluster"] = hc_avg_cos_1d_labels.astype(str)

fig = px.scatter_3d(
    plot_df,
    x="Dim_1",
    y="Dim_2",
    z="Dim_3",
    color="hc_avg_cluster",
    hover_data=plot_df.columns)

fig.show()

ct = pd.crosstab(hc_avg_cos_1d_labels, labels_df)
print(ct)
# Out:
# proj   orb  rsp  rsp_orb
# row_0
# 0       38    1       25
# 1        2   33       25
# 2        8   24        4

# %%
#compute wcv
wcv_hierarchical_avg = {}
for i in range(2,7):
    cluster_labels_avg = hierarchy.cut_tree(hc_avg_cos, n_clusters=i)
    cluster_labels_avg = cluster_labels_avg[:, 0]
    wcv_avg_cos_i = compute_wcv(cluster_labels_avg, low_dim_df)
    wcv_hierarchical_avg[i] = wcv_avg_cos_i

# %%
#compute silhouette scores
sil_hierarchical_avg = {}
range_n_clusters = [2, 3, 4, 5, 6]
# Compute the hierarchical clustering linkage once
hc_avg_cos = hierarchy.linkage(low_dim_df, method="average", metric="cosine")

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 1 columns
    fig, ax1 = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(low_dim_df) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    cluster_labels = hierarchy.cut_tree(hc_avg_cos, n_clusters=n_clusters)
    cluster_labels = cluster_labels[:, 0]

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(
        low_dim_df,
        cluster_labels,
        metric="cosine"
    )

    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )
    sil_hierarchical_avg[n_clusters] = silhouette_avg
    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(
        low_dim_df,
        cluster_labels,
        metric="cosine"
    )

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(
        "Silhouette analysis for Hierarchical clustering on sample data with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.2876590321409099
# For n_clusters = 3 The average silhouette_score is : 0.3063561852534741
# For n_clusters = 4 The average silhouette_score is : 0.2357552012951051
# For n_clusters = 5 The average silhouette_score is : 0.22747540697858
# For n_clusters = 6 The average silhouette_score is : 0.2074472617549275
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>

# %% [markdown]
# # Kmeans ++

# %%
#plot wcv in function of the number of clusters

n_k = np.arange(1,50,1)
rs = 0
wcv = []
fig, ax = plt.subplots(1,1,figsize=(20,4))
for n in range(n_k.shape[0]):
    kmeans_n = KMeans(n_clusters = n_k[n], init = 'k-means++', n_init = 10, random_state=rs).fit(low_dim_df)
    wcv.append(kmeans_n.inertia_)
ax.plot(n_k, wcv, 'k-', marker = 'o', markersize=4)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [<matplotlib.lines.Line2D object at 0x0000024083692210>]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x400 with 1 Axes>

# %% [markdown]
# Looks like the biggest jump is at 2 clustrers but it doesnt seem that k++ captures clear clustering structure. Can try with kernel? --> spectral clustering, from scikit learn documentation: "In practice Spectral Clustering is very useful when the structure of the individual clusters is highly non-convex, or more generally when a measure of the center and spread of the cluster is not a suitable description of the complete cluster, such as when clusters are nested circles on the 2D plane."

# %%
kmeans_tuned = KMeans(n_clusters = 2, init = 'k-means++', n_init = 10, random_state=rs).fit(low_dim_df)
kmeans_cluster_labels = kmeans_tuned.labels_

plot_df["kmeans_cluster"] = kmeans_cluster_labels.astype(str)

fig = px.scatter_3d(
    plot_df,
    x="Dim_1",
    y="Dim_2",
    z="Dim_3",
    color="kmeans_cluster",
    hover_data=plot_df.columns)

fig.show()

ct = pd.crosstab(kmeans_cluster_labels, labels_df)
print(ct)
# Out:
# proj   orb  rsp  rsp_orb
# row_0
# 0       16   58       37
# 1       32    0       17

# %%
#compute wcv
wcv_kmeans = {}
for i in range(2,7):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', n_init = 15, random_state=rs).fit(low_dim_df)
    wcv_kmeans_i = kmeans.inertia_
    wcv_kmeans[i] = wcv_kmeans_i

# %%
# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.
range_n_clusters = [2, 3, 4, 5, 6]
sil_kmeans = {}

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1 = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(low_dim_df) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters = n_clusters, init = 'k-means++', n_init = 15, random_state=rs)
    cluster_labels = clusterer.fit_predict(low_dim_df)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(low_dim_df, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )
    sil_kmeans[n_clusters] = silhouette_avg
    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(low_dim_df, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(
        "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.3348315858077528
# For n_clusters = 3 The average silhouette_score is : 0.20538430382667452
# For n_clusters = 4 The average silhouette_score is : 0.22038976577431937
# For n_clusters = 5 The average silhouette_score is : 0.17201163228269303
# For n_clusters = 6 The average silhouette_score is : 0.17449249251229756
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x700 with 1 Axes>

# %% [markdown]
# # Spectral Clustering

# %%
spectral_clus = SpectralClustering(affinity='rbf', gamma=1, assign_labels='kmeans')
spectral_clus.fit(low_dim_df)
# Out:
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# SpectralClustering(gamma=1)

# %% [markdown]
# We select the value of gamma by looking at the average silhouette score for each level of gamma

# %%
n_clusters = [2,3,4,5,6,7,8]
gamma_list = np.linspace(0.05, 3, 30)

tuned_spectral_clus = GridSearchCV(spectral_clus, 
                    param_grid={'gamma': gamma_list, "n_clusters": n_clusters},
                    scoring = spectral_scorer_sil,
                    cv = KFold(n_splits=5, shuffle = True, random_state=rng))

# %%
tuned_spectral_clus.fit(low_dim_df)

print(tuned_spectral_clus.best_params_)
# Out:
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited at iteration 2000 with accuracies
# [1.22333015e-15 5.86027680e-07 3.58811094e-05]
# not reaching the requested tolerance 2.816319465637207e-06.
# Use iteration 1833 instead with accuracy
# 1.1219331157426416e-05.
#
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited postprocessing with accuracies
# [8.39654235e-16 6.16156770e-07 3.30418365e-05]
# not reaching the requested tolerance 2.816319465637207e-06.
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited at iteration 2000 with accuracies
# [1.06254000e-14 5.43755898e-07 1.17817752e-05]
# not reaching the requested tolerance 2.816319465637207e-06.
# Use iteration 1998 instead with accuracy
# 3.0117678406314956e-06.
#
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited postprocessing with accuracies
# [8.12733030e-15 5.30006832e-07 8.50489204e-06]
# not reaching the requested tolerance 2.816319465637207e-06.
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited at iteration 2000 with accuracies
# [2.35049012e-15 1.44816424e-06 3.10763687e-05]
# not reaching the requested tolerance 2.8312206268310547e-06.
# Use iteration 1938 instead with accuracy
# 2.872424348887792e-06.
#
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited postprocessing with accuracies
# [1.93475726e-15 9.39805902e-07 7.67756394e-06]
# not reaching the requested tolerance 2.8312206268310547e-06.
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited at iteration 348 with accuracies
# [4.68705505e-15 2.95827899e-06 2.49823531e-06 1.83119961e-06]
# not reaching the requested tolerance 2.816319465637207e-06.
# Use iteration 348 instead with accuracy
# 1.8219284785634866e-06.
#
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited postprocessing with accuracies
# [2.29503821e-15 2.95828459e-06 2.49822865e-06 1.83119958e-06]
# not reaching the requested tolerance 2.816319465637207e-06.
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited at iteration 2000 with accuracies
# [1.69881376e-15 8.14275481e-07 1.49173668e-05]
# not reaching the requested tolerance 2.816319465637207e-06.
# Use iteration 480 instead with accuracy
# 1.8009277268032627e-06.
#
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited postprocessing with accuracies
# [1.00191702e-15 1.99247288e-06 3.41031025e-06]
# not reaching the requested tolerance 2.816319465637207e-06.
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited at iteration 2000 with accuracies
# [1.83534312e-15 3.84114882e-06 8.68838768e-06]
# not reaching the requested tolerance 2.8312206268310547e-06.
# Use iteration 1793 instead with accuracy
# 1.6023703837870977e-06.
#
#   _, diffusion_map = lobpcg(
# ...
# [2.31009107e-14 1.61361818e-06 1.78622970e-06 2.89683272e-06
#  1.03020934e-06 1.36993964e-06]
# not reaching the requested tolerance 2.8312206268310547e-06.
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited at iteration 2000 with accuracies
# [7.61880515e-15 6.40057885e-08 3.97824174e-07 1.43407968e-06
#  9.54807967e-06 3.48692514e-05]
# not reaching the requested tolerance 2.8312206268310547e-06.
# Use iteration 1794 instead with accuracy
# 2.44978161719852e-06.
#
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited postprocessing with accuracies
# [2.25676519e-15 6.68217831e-08 4.09741996e-07 1.47965104e-06
#  2.45780138e-06 1.02842439e-05]
# not reaching the requested tolerance 2.8312206268310547e-06.
#   _, diffusion_map = lobpcg(
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 tuned_spectral_clus.fit(low_dim_df)
#       2
#       3 print(tuned_spectral_clus.best_params_)
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\model_selection\_search.py:1053, in BaseSearchCV.fit(self, X, y, **params)
#    1047     results = self._format_results(
#    1048         all_candidate_params, n_splits, all_out, all_more_results
#    1049     )
#    1051     return results
# -> 1053 self._run_search(evaluate_candidates)
#    1055 # multimetric is determined here because in the case of a callable
#    1056 # self.scoring the return type is only known after calling
#    1057 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\model_selection\_search.py:1612, in GridSearchCV._run_search(self, evaluate_candidates)
#    1610 def _run_search(self, evaluate_candidates):
#    1611     """Search all candidates in param_grid"""
# -> 1612     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\model_selection\_search.py:999, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     991 if self.verbose > 0:
#     992     print(
#     993         "Fitting {0} folds for each of {1} candidates,"
#     994         " totalling {2} fits".format(
#     995             n_splits, n_candidates, n_candidates * n_splits
#     996         )
#     997     )
# --> 999 out = parallel(
#    1000     delayed(_fit_and_score)(
#    1001         clone(base_estimator),
#    1002         X,
#    1003         y,
#    1004         train=train,
#    1005         test=test,
#    1006         parameters=parameters,
#    1007         split_progress=(split_idx, n_splits),
#    1008         candidate_progress=(cand_idx, n_candidates),
#    1009         **fit_and_score_kwargs,
#    1010     )
#    1011     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1012         enumerate(candidate_params),
#    1013         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1014     )
#    1015 )
#    1017 if len(out) < 1:
#    1018     raise ValueError(
#    1019         "No fits were performed. "
#    1020         "Was the CV iterator empty? "
#    1021         "Were there no candidates?"
#    1022     )
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\model_selection\_validation.py:831, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     829 try:
#     830     if y_train is None:
# --> 831         estimator.fit(X_train, **fit_params)
#     832     else:
#     833         estimator.fit(X_train, y_train, **fit_params)
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\cluster\_spectral.py:760, in SpectralClustering.fit(self, X, y)
#     757     print(f"Computing label assignment using {self.assign_labels}")
#     759 if self.assign_labels == "kmeans":
# --> 760     _, self.labels_, _ = k_means(
#     761         maps,
#     762         self.n_clusters,
#     763         random_state=random_state,
#     764         n_init=self.n_init,
#     765         verbose=self.verbose,
#     766     )
#     767 elif self.assign_labels == "cluster_qr":
#     768     self.labels_ = cluster_qr(maps)
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:455, in k_means(X, n_clusters, sample_weight, init, n_init, max_iter, verbose, tol, random_state, copy_x, algorithm, return_n_iter)
#     296 @validate_params(
#     297     {
#     298         "X": ["array-like", "sparse matrix"],
#    (...)    317     return_n_iter=False,
#     318 ):
#     319     """Perform K-means clustering algorithm.
#     320
#     321     Read more in the :ref:`User Guide <k_means>`.
#    (...)    443     16.0
#     444     """
#     445     est = KMeans(
#     446         n_clusters=n_clusters,
#     447         init=init,
#     448         n_init=n_init,
#     449         max_iter=max_iter,
#     450         verbose=verbose,
#     451         tol=tol,
#     452         random_state=random_state,
#     453         copy_x=copy_x,
#     454         algorithm=algorithm,
# --> 455     ).fit(X, sample_weight=sample_weight)
#     456     if return_n_iter:
#     457         return est.cluster_centers_, est.labels_, est.inertia_, est.n_iter_
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1516, in KMeans.fit(self, X, y, sample_weight)
#    1513     print("Initialization complete")
#    1515 # run a k-means once
# -> 1516 labels, inertia, centers, n_iter_ = kmeans_single(
#    1517     X,
#    1518     sample_weight,
#    1519     centers_init,
#    1520     max_iter=self.max_iter,
#    1521     verbose=self.verbose,
#    1522     tol=self._tol,
#    1523     n_threads=self._n_threads,
#    1524 )
#    1526 # determine if these results are the best so far
#    1527 # we chose a new run if it has a better inertia and the clustering is
#    1528 # different from the best so far (it's possible that the inertia is
#    1529 # slightly better even if the clustering is the same with potentially
#    1530 # permuted labels, due to rounding errors)
#    1531 if best_inertia is None or (
#    1532     inertia < best_inertia
#    1533     and not _is_same_clustering(labels, best_labels, self.n_clusters)
#    1534 ):
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\utils\parallel.py:210, in _threadpool_controller_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 controller = _get_threadpool_controller()
#     209 with controller.limit(limits=limits, user_api=user_api):
# --> 210     return func(*args, **kwargs)
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:706, in _kmeans_single_lloyd(X, sample_weight, centers_init, max_iter, verbose, tol, n_threads)
#     703 strict_convergence = False
#     705 for i in range(max_iter):
# --> 706     lloyd_iter(
#     707         X,
#     708         sample_weight,
#     709         centers,
#     710         centers_new,
#     711         weight_in_clusters,
#     712         labels,
#     713         center_shift,
#     714         n_threads,
#     715     )
#     717     if verbose:
#     718         inertia = _inertia(X, sample_weight, centers, labels, n_threads)
#
# File sklearn/cluster/_k_means_lloyd.pyx:160, in sklearn.cluster._k_means_lloyd.lloyd_iter_chunked_dense()
# --> 160 'Could not get source, probably due dynamically evaluated source code.'
#
# File sklearn/cluster/_k_means_common.pyx:177, in sklearn.cluster._k_means_common._relocate_empty_clusters_dense()
# --> 177 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\ricca\miniconda3\Lib\site-packages\numpy\_core\multiarray.py:403, in where(condition, x, y)
#     311     """
#     312     inner(a, b, /)
#     313
#    (...)    398
#     399     """
#     400     return (a, b)
# --> 403 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     404 def where(condition, x=None, y=None, /):
#     405     """
#     406     where(condition, [x, y], /)
#     407
#    (...)    474            [ 0,  3, -1]])
#     475     """
#     476     return (condition, x, y)
#
# KeyboardInterrupt:

# %%
#Get average silhouette score accross solution with cluster 2,3,4,5,6 for each value of gamma

cv_results = pd.DataFrame(tuned_spectral_clus.cv_results_)

cv_results["silhouette"] = cv_results["mean_test_score"]

target_clusters = [2, 3, 4, 5, 6]

filtered_results = cv_results[
    cv_results["param_n_clusters"].isin(target_clusters)
]

gamma_summary = (
    filtered_results
    .groupby("param_gamma")
    .agg(
        mean_silhouette=("silhouette", "mean"),
        max_silhouette=("silhouette", "max"),
        std_silhouette=("silhouette", "std")
    )
    .sort_values("mean_silhouette", ascending=False)
)

gamma_summary.head()

# %% [markdown]
# Plot silhouette score vs gamma and silhouette score vs n_clusters --> choose paramteres, fit the corresponding model.

# %%
n_k = np.arange(2,50,1)
rs = 0
sil = []
fig, ax = plt.subplots(1,1,figsize=(20,4))
for n in range(n_k.shape[0]):
    spectral_clus_tuned = SpectralClustering(affinity='rbf', assign_labels='kmeans', gamma=0.05, n_clusters=n_k[n])
    labels = spectral_clus_tuned.fit_predict(low_dim_df)
    score =  silhouette_score(low_dim_df,labels)
    sil.append(score)
ax.plot(n_k, sil, 'k-', marker = 'o', markersize=4)

# %% [markdown]
# 2 clusters seems to be the most suitable choice also in this case

# %%
spectral_clus_tuned = SpectralClustering(affinity='rbf', assign_labels='kmeans', gamma=0.05, n_clusters=2)
spectral_cluster_labels = spectral_clus_tuned.fit_predict(low_dim_df)

plot_df["spectral_cluster"] = spectral_cluster_labels.astype(str)

fig = px.scatter_3d(
    plot_df,
    x="Dim_1",
    y="Dim_2",
    z="Dim_3",
    color="spectral_cluster",
    hover_data=plot_df.columns)

fig.show()

ct = pd.crosstab(spectral_cluster_labels, labels_df)
print(ct)

# %%
wcv_spectral = {}
for i in range(2,7):
    spectral_clus_tuned = SpectralClustering(affinity='rbf', assign_labels='kmeans', gamma=0.05, n_clusters=i)
    labels_spec = spectral_clus_tuned.fit_predict(low_dim_df)
    wcv_spec_i = compute_wcv(labels_spec, low_dim_df)
    wcv_spectral[i] = wcv_spec_i

# %%
#silhouette

range_n_clusters = [2, 3, 4, 5, 6]
sil_spectral = {}
for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1 = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(low_dim_df) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = SpectralClustering(affinity='rbf', assign_labels='kmeans', gamma=0.010974, n_clusters=n_clusters)
    cluster_labels = clusterer.fit_predict(low_dim_df)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(low_dim_df, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )
    sil_spectral[n_clusters] = silhouette_avg
    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(low_dim_df, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(
        "Silhouette analysis for Spectral clustering on sample data with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()

# %% [markdown]
# # Summary on clustering

# %%
summary_table = pd.DataFrame(
    {
        (2, "WCV"): [
            wcv_comp_cos[2],
            wcv_kmeans[2],
            wcv_spectral[2],
            wcv_hierarchical_avg[2]
        ],
        (2, "Silhouette"): [
            sil_hierarchical[2],
            sil_kmeans[2],
            sil_spectral[2],
            sil_hierarchical_avg[2]
        ],

        (3, "WCV"): [
            wcv_comp_cos[3],
            wcv_kmeans[3],
            wcv_spectral[3],
            wcv_hierarchical_avg[3]
        ],
        (3, "Silhouette"): [
            sil_hierarchical[3],
            sil_kmeans[3],
            sil_spectral[3],
            sil_hierarchical_avg[3]
        ],

        (4, "WCV"): [
            wcv_comp_cos[4],
            wcv_kmeans[4],
            wcv_spectral[4],
            wcv_hierarchical_avg[4]
        ],
        (4, "Silhouette"): [
            sil_hierarchical[4],
            sil_kmeans[4],
            sil_spectral[4],
            sil_hierarchical_avg[4]
        ],

        (5, "WCV"): [
            wcv_comp_cos[5],
            wcv_kmeans[5],
            wcv_spectral[5],
            wcv_hierarchical_avg[5]
        ],
        (5, "Silhouette"): [
            sil_hierarchical[5],
            sil_kmeans[5],
            sil_spectral[5],
            sil_hierarchical_avg[5]
        ],

        (6, "WCV"): [
            wcv_comp_cos[6],
            wcv_kmeans[6],
            wcv_spectral[6],
            wcv_hierarchical_avg[6]
        ],
        (6, "Silhouette"): [
            sil_hierarchical[6],
            sil_kmeans[6],
            sil_spectral[6],
            sil_hierarchical_avg[6]
        ],
    },
    index=["Hierarchical", "KMeans++", "Spectral", "Hierarchical_avg"]
)

summary_table.columns.names = ["n_clusters", "Metric"]

summary_table
# summary_table.to_csv("summary_table_no_log.csv")
